# %% [markdown]
# # Proyek Analisis Data: [E-commerce Public Dataset]
# - **Nama:** [Nafisah Rizqi Khairriyah]
# - **Email:** [nafisahrk@gmail.com]
# - **ID Dicoding:** [nafisah_rizqi_khairriyah_r7Oa]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# * Bagaimana performa penjualan dan revenue perusahaan dalam beberapa bulan terakhir?
# * Bagaimana demografi pelanggan yang kita miliki?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# Menampilkan tabel customers

# %%
customers_df = pd.read_csv("customers_dataset.csv")
customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %% [markdown]
# Menampilkan tabel geolocation

# %%
geolocation_df = pd.read_csv("geolocation_dataset.csv")
geolocation_df.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037           -23.55           -46.64
# 1                         1046           -23.55           -46.64
# 2                         1046           -23.55           -46.64
# 3                         1041           -23.54           -46.64
# 4                         1035           -23.54           -46.64
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %% [markdown]
# Menampilkan tabel order_items

# %%
order_items_df = pd.read_csv("order_items_dataset.csv")
order_items_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date  price  freight_value
# 0  2017-09-19 09:45:35  58.90          13.29
# 1  2017-05-03 11:05:13 239.90          19.93
# 2  2018-01-18 14:48:30 199.00          17.87
# 3  2018-08-15 10:10:18  12.99          12.79
# ...

# %% [markdown]
# Menampilkan tabel order_payments

# %%
order_payments_df = pd.read_csv("order_payments_dataset.csv")
order_payments_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %% [markdown]
# Menampilkan tabel order_reviews

# %%
order_reviews_df = pd.read_csv("order_reviews_dataset.csv")
order_reviews_df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %% [markdown]
# Menampilkan tabel orders

# %%
orders_df = pd.read_csv("orders_dataset.csv")
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# Menampilkan tabel product_category_name

# %%
product_category_name_translation_df = pd.read_csv("product_category_name_translation.csv")
product_category_name_translation_df.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %% [markdown]
# Menampilkan tabel products

# %%
products_df = pd.read_csv("products_dataset.csv")
products_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                40.00                      287.00                1.00
# 1                44.00                      276.00                1.00
# 2                46.00                      250.00                1.00
# 3                27.00                      261.00                1.00
# 4                37.00                      402.00                4.00
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0            225.00              16.00              10.00             14.00
# ...

# %% [markdown]
# Menampilkan tabel sellers

# %%
sellers_df = pd.read_csv("sellers_dataset.csv")
sellers_df.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# **Insight:**
# - Pada tahap gathering berguna untuk mengumpulkan informasi yang diperlukan untuk analisis lebih lanjut
# -Pengumpulan data dari sembilan tabel memungkinkan untuk mengevaluasi kualitas data secara menyeluruh. Ini penting untuk memastikan bahwa data yang akan dianalisis adalah akurat, relevan, dan konsisten.

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# Menilai tabel customer_df

# %% [markdown]
# Mengecek tipe data pada tabel info

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %% [markdown]
# Mengecek apakah ada missing values

# %%
customers_df.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %% [markdown]
# Mengecek apakah ada duplikasi data

# %%
print("Jumlah duplikasi: ", customers_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
customers_df.describe()
# Out:
#        customer_zip_code_prefix
# count                  99441.00
# mean                   35137.47
# std                    29797.94
# min                     1003.00
# 25%                    11347.00
# 50%                    24416.00
# 75%                    58900.00
# max                    99990.00

# %% [markdown]
# Menilai tabel geolocation_df

# %% [markdown]
# Mengecek tipe data

# %%
geolocation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %% [markdown]
# Mengecek apakah ada missing values

# %%
geolocation_df.isna().sum()
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %% [markdown]
# Mengecek apakah ada duplikasi data

# %%
print("Jumlah duplikasi: ", geolocation_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  261831

# %%
geolocation_df.describe()
# Out:
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# count                   1000163.00       1000163.00       1000163.00
# mean                      36574.17           -21.18           -46.39
# std                       30549.34             5.72             4.27
# min                        1001.00           -36.61          -101.47
# 25%                       11075.00           -23.60           -48.57
# 50%                       26530.00           -22.92           -46.64
# 75%                       63504.00           -19.98           -43.77
# max                       99990.00            45.07           121.11

# %% [markdown]
# Menilai tabel order_items_df

# %% [markdown]
# Mengecek tipe data

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %% [markdown]
# Mengubah tipe data price

# %%
order_items_df['price'] = pd.to_numeric(order_items_df['price'], errors='coerce')

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
order_items_df.describe()
# Out:
#        order_item_id     price  freight_value
# count      112650.00 112650.00      112650.00
# mean            1.20    120.65          19.99
# std             0.71    183.63          15.81
# min             1.00      0.85           0.00
# 25%             1.00     39.90          13.08
# 50%             1.00     74.99          16.26
# 75%             1.00    134.90          21.15
# max            21.00   6735.00         409.68

# %%
order_items_df.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
print("Jumlah duplikasi: ", order_items_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
order_items_df.describe()
# Out:
#        order_item_id     price  freight_value
# count      112650.00 112650.00      112650.00
# mean            1.20    120.65          19.99
# std             0.71    183.63          15.81
# min             1.00      0.85           0.00
# 25%             1.00     39.90          13.08
# 50%             1.00     74.99          16.26
# 75%             1.00    134.90          21.15
# max            21.00   6735.00         409.68

# %% [markdown]
# Penilaian tabel order_payments_df

# %% [markdown]
# Mengecek tipe data tabel order_payments_df

# %%
order_payments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %% [markdown]
# Mengecek apakah ada missing value pada tabel

# %%
order_payments_df.isna().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %% [markdown]
# Mengecek apakah ada data yang terduplikasi

# %%
print("Jumlah duplikasi: ",order_payments_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# menampilkan tabel order_payments_df

# %%
order_payments_df.describe()
# Out:
#        payment_sequential  payment_installments  payment_value
# count           103886.00             103886.00      103886.00
# mean                 1.09                  2.85         154.10
# std                  0.71                  2.69         217.49
# min                  1.00                  0.00           0.00
# 25%                  1.00                  1.00          56.79
# 50%                  1.00                  1.00         100.00
# 75%                  1.00                  4.00         171.84
# max                 29.00                 24.00       13664.08

# %% [markdown]
# Menilai product order_reviews

# %% [markdown]
# Mengecek tipe data tabel order_reviews

# %%
order_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %% [markdown]
# Mengecek apakah ada missing values pada tabel tersebut

# %%
order_reviews_df.isna().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %% [markdown]
# Mengecek apakah ada data yang terduplikasi

# %%
print("Jumlah duplikasi: ", order_reviews_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# menampilkan tabel order_reviews

# %%
order_reviews_df.describe()
# Out:
#        review_score
# count      99224.00
# mean           4.09
# std            1.35
# min            1.00
# 25%            4.00
# 50%            5.00
# 75%            5.00
# max            5.00

# %% [markdown]
# Menilai tabel orders_df

# %% [markdown]
# Mengecek tipe data tabel orders

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %% [markdown]
# Mengecek apakah ada missing values pada tabel tersebut

# %%
orders_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %% [markdown]
# Mengecek apakah ada data yang terduplikasi

# %%
print("Jumlah duplikasi: ", customers_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# Menampilkan tabel orders

# %%
orders_df.describe()
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-04-11 10:48:14  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# ...

# %% [markdown]
# Menilai tabel product_category_name_translation_df

# %% [markdown]
# Mengecek type data tabel product_category_name_translation

# %%
product_category_name_translation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %% [markdown]
# Mengecek apakah ada missing values pada tabel

# %%
product_category_name_translation_df.isna().sum()
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %% [markdown]
# Mengecek apakah ada data yang terduplikasi

# %%
print("Jumlah duplikasi: ", product_category_name_translation_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# Menampilkan info tabel product_category_name_translation

# %%
product_category_name_translation_df.describe()
# Out:
#        product_category_name product_category_name_english
# count                     71                            71
# unique                    71                            71
# top             beleza_saude                 health_beauty
# freq                       1                             1

# %% [markdown]
# Menilai tabel products_df

# %% [markdown]
# Mengecek tipe data tabel products

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %% [markdown]
# Mengecek apakah ada missing value pada tabel

# %%
products_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %% [markdown]
# Mengecek apakah ada data yang terduplikat

# %%
print("Jumlah duplikasi: ", products_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# Menampilkan tabel products

# %%
products_df.describe()
# Out:
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count             32341.00                    32341.00            32341.00
# mean                 48.48                      771.50                2.19
# std                  10.25                      635.12                1.74
# min                   5.00                        4.00                1.00
# 25%                  42.00                      339.00                1.00
# 50%                  51.00                      595.00                1.00
# 75%                  57.00                      972.00                3.00
# max                  76.00                     3992.00               20.00
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count          32949.00           32949.00           32949.00
# mean            2276.47              30.82              16.94
# std             4282.04              16.91              13.64
# ...

# %% [markdown]
# Menilai tabel sellers_df

# %% [markdown]
# Mengecek tipe data tabel sellers

# %%
sellers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %% [markdown]
# Mengecek apakah ada missing values pada tabel

# %%
sellers_df.isna().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %% [markdown]
# Mengecek apakah ada data yang terduplikasi

# %%
print("Jumlah duplikasi: ", sellers_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# Menampilkan tabel seller

# %%
sellers_df.describe()
# Out:
#        seller_zip_code_prefix
# count                 3095.00
# mean                 32291.06
# std                  32713.45
# min                   1001.00
# 25%                   7093.50
# 50%                  14940.00
# 75%                  64552.50
# max                  99730.00

# %% [markdown]
# **Insight:**
# - Pada tahap assesing data ini menilai apakah type data tersebut sudah benar, apakah data terdapat missing value pada data tersebut, apakah terdapat duplicate data pada data tersebut, apakah terdapat inacurate value pada data tersebut
# - Ditemukan beberapa masalah pada data pada beberapa table

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# Pada proses cleaning data ini dilakukan setelah mengetahui masalah yang ada pada tabel

# %% [markdown]
# Membersihkan tabel geolocation_df

# %%
geolocation_df.duplicated().sum()
# Out:
# 261831

# %%
geolocation_df.drop_duplicates(inplace=True)

# %%
print("Jumlah duplikasi: ", geolocation_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
geolocation_df.isna().sum()
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %%
geolocation_df[geolocation_df.geolocation_lng.isna()]
# Out:
# Empty DataFrame
# Columns: [geolocation_zip_code_prefix, geolocation_lat, geolocation_lng, geolocation_city, geolocation_state]
# Index: []

# %%
geolocation_df.geolocation_lng.value_counts()
# Out:
# geolocation_lng
# -47.87    10
# -41.32     9
# -42.94     7
# -48.45     7
# -47.88     7
#           ..
# -48.56     1
# -48.38     1
# -48.17     1
# -48.57     1
# -51.85     1
# Name: count, Length: 717613, dtype: int64

# %%
geolocation_df.fillna(value="-46.695282", inplace=True)

# %%
geolocation_df.isna().sum()
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %% [markdown]
# Membersihkan tabel order_reviews_df

# %%
order_reviews_df[order_reviews_df.review_comment_title.isna()]
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %%
order_reviews_df.review_comment_title.value_counts()
# Out:
# review_comment_title
# Recomendo                    423
# recomendo                    345
# Bom                          293
# super recomendo              270
# Excelente                    248
#                             ...
# Luminaria sobrepor led 18      1
# Não recebi.                    1
# produto com lacre violado      1
# Atraso Entrega                 1
# Foto enganosa                  1
# Name: count, Length: 4527, dtype: int64

# %%
order_reviews_df.fillna(value="Recomendo", inplace=True)

# %%
order_reviews_df.isna().sum()
# Out:
# review_id                  0
# order_id                   0
# review_score               0
# review_comment_title       0
# review_comment_message     0
# review_creation_date       0
# review_answer_timestamp    0
# dtype: int64

# %% [markdown]
# Menangani tabel orders_df

# %%
datetime_columns = ["order_purchase_timestamp", "order_approved_at", "order_delivered_carrier_date","order_delivered_customer_date", "order_estimated_delivery_date"]

for column in datetime_columns:
  orders_df[column] = pd.to_datetime(orders_df[column])

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %%
orders_df[orders_df.order_approved_at.isna()]
# Out:
#                                order_id                       customer_id  \
# 1130   00b1cb0320190ca0daa2c88b35206009  3532ba38a3fd242259a514ac2b6ae6b6
# 1801   ed3efbd3a87bea76c2812c66a0b32219  191984a8ba4cbb2145acb4fe35b69664
# 1868   df8282afe61008dc26c6c31011474d02  aa797b187b5466bc6925aaaa4bb3bed1
# 2029   8d4c637f1accf7a88a4555f02741e606  b1dd715db389a2077f43174e7a675d07
# 2161   7a9d4c7f9b068337875b95465330f2fc  7f71ae48074c0cfec9195f88fcbfac55
# ...                                 ...                               ...
# 97696  5a00b4d35edffc56b825c3646a99ba9d  6a3bdf004ca96338fb5fad1b8d93c2e6
# 98415  227c804e2a44760671a6a5697ea549e4  62e7477e75e542243ee62a0ba73f410f
# 98909  e49e7ce1471b4693482d40c2bd3ad196  e4e7ab3f449aeb401f0216f86c2104db
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
#
#       order_status order_purchase_timestamp order_approved_at  \
# ...

# %%
orders_df.order_approved_at.value_counts()
# Out:
# order_approved_at
# 2018-02-27 04:31:10    9
# 2017-11-07 07:30:38    7
# 2018-02-27 04:31:01    7
# 2018-02-06 05:31:52    7
# 2017-11-07 07:30:29    7
#                       ..
# 2018-08-22 11:50:14    1
# 2017-09-22 11:27:36    1
# 2018-03-07 16:40:32    1
# 2017-08-08 10:50:15    1
# 2018-03-09 11:20:28    1
# Name: count, Length: 90733, dtype: int64

# %%
orders_df.fillna(value="2018-02-27 04:31:10	", inplace=True)

# %%
orders_df.isna().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# dtype: int64

# %% [markdown]
# Menangani tabel products_df

# %%
products_df[products_df.product_category_name.isna()]
# Out:
#                              product_id product_category_name  \
# 105    a41e356c76fab66334f36de622ecbd3a                   NaN
# 128    d8dee61c2034d6d075997acef1870e9b                   NaN
# 145    56139431d72cd51f19eb9f7dae4d1617                   NaN
# 154    46b48281eb6d663ced748f324108c733                   NaN
# 197    5fb61f482620cb672f5e586bb132eae9                   NaN
# ...                                 ...                   ...
# 32515  b0a0c5dd78e644373b199380612c350a                   NaN
# 32589  10dbe0fbaa2c505123c17fdc34a63c56                   NaN
# 32616  bd2ada37b58ae94cc838b9c0569fecd8                   NaN
# 32772  fa51e914046aab32764c41356b9d4ea4                   NaN
# 32852  c4ceee876c82b8328e9c293fa0e1989b                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 105                    NaN                         NaN                 NaN
# ...

# %%
products_df.product_category_name.value_counts()
# Out:
# product_category_name
# cama_mesa_banho                  3029
# esporte_lazer                    2867
# moveis_decoracao                 2657
# beleza_saude                     2444
# utilidades_domesticas            2335
#                                  ...
# fashion_roupa_infanto_juvenil       5
# casa_conforto_2                     5
# pc_gamer                            3
# seguros_e_servicos                  2
# cds_dvds_musicais                   1
# Name: count, Length: 73, dtype: int64

# %%
products_df.fillna(value="cama_mesa_banho", inplace=True)
# Out:
# <ipython-input-392-43746969d17e>:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'cama_mesa_banho' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   products_df.fillna(value="cama_mesa_banho", inplace=True)

# %%
products_df.isna().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %%
orders_order_items_df['order_purchase_timestamp'] = pd.to_datetime(orders_order_items_df['order_purchase_timestamp'])

# %% [markdown]
# **Insight:**
# - Penanganan dilakukan pada beberapa tabel seperti handling missing values, handling duplicate data, handling tipe data

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
orders_df.describe(include="all")
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
# mean                                 NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#        order_status       order_purchase_timestamp  \
# count         99441                          99441
# ...

# %%
order_items_df.describe(include="all")
# Out:
#                                 order_id  order_item_id  \
# count                             112650      112650.00
# unique                             98666            NaN
# top     8272b63d03f5f79c56e9e4120aec44ef            NaN
# freq                                  21            NaN
# mean                                 NaN           1.20
# std                                  NaN           0.71
# min                                  NaN           1.00
# 25%                                  NaN           1.00
# 50%                                  NaN           1.00
# 75%                                  NaN           1.00
# max                                  NaN          21.00
#
#                               product_id                         seller_id  \
# count                             112650                            112650
# unique                             32951                              3095
# ...

# %% [markdown]
# Menggabungkan tabel order dan orders_items

# %%
orders_order_items_df = pd.merge(
    left=orders_df,
    right=order_items_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
orders_order_items_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# Menampilkan tabel year_month, total_orders,dan price yang digunakan untuk menjawab pertanyaan "Bagaimana performa penjualan dan revenue perusahaan dalam beberapa bulan terakhir?"

# %%
orders_order_items_df['order_purchase_timestamp'] = pd.to_datetime(orders_order_items_df['order_purchase_timestamp'])
orders_order_items_df['month'] = orders_order_items_df['order_purchase_timestamp'].dt.month

# %%
orders_order_items_df.groupby(['month']).agg({
    'order_id': 'nunique',
    'price': 'sum',
}).rename(columns={'order_id': 'total_orders'}).reset_index()
# Out:
#     month  total_orders      price
# 0       1          8069 1070343.23
# 1       2          8508 1091481.73
# 2       3          9893 1357557.74
# 3       4          9343 1356574.98
# 4       5         10573 1502588.82
# 5       6          9412 1298162.91
# 6       7         10318 1393538.70
# 7       8         10843 1428658.01
# 8       9          4305  624814.05
# 9      10          4959  713727.09
# 10     11          7544 1010271.37
# 11     12          5674  743925.07

# %%
customers_df.describe(include="all")
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %% [markdown]
# Menampilkan asal kota pelanggan yang paling banyak memberi hingga yang paling sedikit

# %%
customers_df.groupby(by="customer_city").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
#                   ...
# ibiara                1
# rio espera            1
# rio dos indios        1
# rio dos cedros        1
# lagoao                1
# Name: customer_id, Length: 4119, dtype: int64

# %% [markdown]
# Menampilkan asal negara pelanggan yang paling banyak memberi hingga yang paling sedikit

# %%
customers_df.groupby(by="customer_state").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: customer_id, dtype: int64

# %%
orders_customers_df = pd.merge(
    left=orders_df,
    right=customers_df,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
orders_customers_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
all_df = pd.merge(
    left=orders_order_items_df,
    right=orders_customers_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
all_df.head()
# Out:
#                            order_id                     customer_id_x  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status_x order_purchase_timestamp_x order_approved_at_x  \
# 0      delivered        2017-10-02 10:56:33 2017-10-02 11:07:15
# 1      delivered        2018-07-24 20:41:37 2018-07-26 03:24:27
# 2      delivered        2018-08-08 08:38:49 2018-08-08 08:55:23
# 3      delivered        2017-11-18 19:28:06 2017-11-18 19:45:59
# 4      delivered        2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date_x order_delivered_customer_date_x  \
# 0            2017-10-04 19:55:00             2017-10-10 21:25:13
# ...

# %%
all_df.to_csv("all_data.csv", index=False)

# %% [markdown]
# **Insight:**
# - Peningkatan signifikan terjadi pada November 2017, yang mungkin disebabkan oleh periode promosi atau liburan, karena jumlah pesanan dan pendapatan mencapai puncak tertinggi.
# -Tren penjualan cenderung naik dari awal 2017 hingga pertengahan 2018, meskipun ada beberapa fluktuasi di bulan-bulan tertentu.
# - Berdasarkan hasil EDA pada tabel customers tersebut diketahui bahwa pelanggan kita paling banyak berada di kota Sao Paulo, Rio de Janeiro, Belo Horizonte, Brasilia, Curitiba. Selain itu, pelanggan paling banyak berasal dari negara Sao Paulo

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# Pada tahap ini dilakukan visualisasi data setelah mendapatkan jawaban dari permasalahan tersebut

# %% [markdown]
# ### Pertanyaan 1:Bagaimana performa penjualan dan revenue perusahaan dalam beberapa bulan terakhir?

# %%
monthly_orders_df = orders_order_items_df.groupby('month').agg({
    'order_id': 'nunique',
    'price': 'sum',
}).reset_index()
monthly_orders_df = monthly_orders_df.reset_index()
monthly_orders_df.rename(columns={
    'order_id': 'total_orders',
    'price': 'price'
}, inplace=True)

# Menampilkan hasil akhir
print(monthly_orders_df)
# Out:
#     index  month  total_orders      price
# 0       0      1          8069 1070343.23
# 1       1      2          8508 1091481.73
# 2       2      3          9893 1357557.74
# 3       3      4          9343 1356574.98
# 4       4      5         10573 1502588.82
# 5       5      6          9412 1298162.91
# 6       6      7         10318 1393538.70
# 7       7      8         10843 1428658.01
# 8       8      9          4305  624814.05
# 9       9     10          4959  713727.09
# 10     10     11          7544 1010271.37
# 11     11     12          5674  743925.07

# %%
monthly_orders_df = orders_order_items_df.groupby('month').agg({
    'order_id': 'nunique',
    'price': 'sum',
}).reset_index()
monthly_orders_df = monthly_orders_df.reset_index()
monthly_orders_df.rename(columns={
    'order_id': 'total_orders',
    'price': 'price'
}, inplace=True)

plt.figure(figsize=(10, 5))
plt.plot(monthly_orders_df["month"], monthly_orders_df["total_orders"], marker='o', linewidth=2, color="#72BCD4")
plt.title("Number of Orders per Month (2021)", loc="center", fontsize=20)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# ### Pertanyaan 2: Bagaimana demografi pelanggan yang kita miliki?

# %%
bystate_df = customers_df.groupby(by="customer_state").customer_id.nunique().reset_index()
bystate_df.rename(columns={
    "customer_id": "customer_count"
}, inplace=True)
bystate_df
plt.figure(figsize=(10, 5))
colors_ = ["#72BCD4"] + ["#72BCD4"] * (len(bystate_df)-1)
sns.barplot(
    x="customer_count",
    y="customer_state",
    data=bystate_df.sort_values(by="customer_count", ascending=False),
    palette=colors_,
    legend=False
)
plt.title("Number of Customer by States", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='y', labelsize=12)
plt.show()

# %%
all_df.to_csv("all_data.csv", index=False)

# %% [markdown]
# **Insight:**
# - Diatas merupakan hasil analisis data yang menunjukkan number of orders per month dan number of customer by states

# %% [markdown]
# #Analisis Lanjutan (Opsional)

# %%
# RFM Analysis Function
def rfm_analysis(all_df):
    # Convert order_date to datetime
    all_df['order_purchase_timestamp_x'] = pd.to_datetime(all_df['order_purchase_timestamp_x'])

    # Create a reference date for recency calculation
    reference_date = all_df['order_purchase_timestamp_x'].max() + pd.DateOffset(days=1)

    # Calculate RFM values
    rfm_df = all_df.groupby('order_id').agg({
        'order_purchase_timestamp_x': lambda x: (reference_date - x.max()).days,  # Recency
        'product_id': 'count',  # Frequency
        'price': 'sum'  # Monetary
    }).reset_index()

    rfm_df.columns = ['customer_id', 'recency', 'frequency', 'monetary']

    return rfm_df

# Calculate RFM values
rfm_df = rfm_analysis(all_df)

# Visualize Recency
plt.figure(figsize=(12, 6))
sns.barplot(
    x="customer_id",
    y="recency",
    data=rfm_df.sort_values(by="recency", ascending=True).head(5),
    palette=["#72BCD4"] * 5,  # Same color for all bars
    legend=False  # Disabling legend
)
plt.title('By Recency (days)', fontsize=16)
plt.xlabel('Customer ID', fontsize=12)
plt.ylabel('Recency (Hari)', fontsize=12)
plt.show()

# Visualize Frequency
plt.figure(figsize=(12, 6))
sns.barplot(
    x="customer_id",
    y="frequency",
    data=rfm_df.sort_values(by="frequency", ascending=False).head(5),
    palette=["#72BCD4"] * 5,  # Same color for all bars
    legend=False  # Disabling legend
)
plt.title('By Frequency', fontsize=16)
plt.xlabel('Customer ID', fontsize=12)
plt.ylabel('Frequency (Jumlah Pembelian)', fontsize=12)
plt.show()

# Visualize Monetary
plt.figure(figsize=(12, 6))
sns.barplot(
    x="customer_id",
    y="monetary",
    data=rfm_df.sort_values(by="monetary", ascending=False).head(5),
    palette=["#72BCD4"] * 5,  # Same color for all bars
    legend=False  # Disabling legend
)
plt.title('By Monetary', fontsize=16)
plt.xlabel('Customer ID', fontsize=12)
plt.ylabel('Monetary (Total Pengeluaran)', fontsize=12)
plt.show()

# %%
rfm_df.describe(include="all")
# Out:
#                              customer_id  recency  frequency  monetary
# count                              99441 99441.00   99441.00  99441.00
# unique                             99441      NaN        NaN       NaN
# top     00010242fe8c5a6d1ba2dd792cb16214      NaN        NaN       NaN
# freq                                   1      NaN        NaN       NaN
# mean                                 NaN   290.90       1.13    136.68
# std                                  NaN   153.67       0.55    210.17
# min                                  NaN     1.00       0.00      0.00
# 25%                                  NaN   167.00       1.00     45.00
# 50%                                  NaN   272.00       1.00     85.00
# 75%                                  NaN   401.00       1.00    149.90
# max                                  NaN   773.00      21.00  13440.00

# %% [markdown]
# Proses analisis RFM ini memberikan gambaran yang jelas tentang perilaku pelanggan berdasarkan tiga parameter kunci:
#
#
# *   Recency menunjukkan seberapa baru pelanggan melakukan pembelian.
# *   Frequency menunjukkan seberapa sering pelanggan melakukan pembelian
# *   Monetary menunjukkan total pengeluaran pelanggan.
#
# Dengan analisis ini, perusahaan dapat memahami dan mengelompokkan pelanggan mereka berdasarkan pola belanja, yang selanjutnya bisa digunakan untuk merancang strategi pemasaran yang lebih efektif dan meningkatkan loyalitas pelanggan.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# * Data mengenai jumlah pesanan dan total pendapatan per bulan menunjukkan bahwa perusahaan mengalami fluktuasi yang signifikan sepanjang tahun. Bulan Mei mencatatkan performa terbaik dengan total 10.573 pesanan dan pendapatan mencapai 1.502.588,82, menunjukkan bulan yang sangat menguntungkan. Sebaliknya, bulan September terlihat sebagai bulan terendah dengan hanya 4.305 pesanan dan pendapatan sebesar 624.814,05. Tren ini mengindikasikan adanya pola musiman dalam perilaku konsumen, di mana bulan-bulan tertentu, terutama dari Mei hingga Agustus, menunjukkan tingkat aktivitas belanja yang lebih tinggi dibandingkan bulan lainnya. Oleh karena itu, penting bagi perusahaan untuk menganalisis lebih dalam faktor-faktor yang memengaruhi penurunan penjualan di bulan-bulan tertentu dan mengoptimalkan strategi pemasaran untuk memanfaatkan periode penjualan yang menguntungkan.
# * Hasil analisis data menunjukkan bahwa demografi pelanggan yang kita miliki   mayoritas berasal dari provinsi di wilayah tenggara, terutama São Paulo, yang mendominasi dengan jumlah pelanggan tertinggi. Sementara itu, wilayah utara dan timur laut memiliki jumlah pelanggan yang jauh lebih rendah. Hal ini menunjukkan fokus perusahaan yang kuat pada pasar di wilayah tenggara dan potensi pertumbuhan di wilayah lainnya yang kurang terlayani. Untuk memanfaatkan potensi pertumbuhan di wilayah utara dan timur laut, perusahaan dapat mempertimbangkan untuk mengembangkan strategi pemasaran yang lebih agresif, termasuk kampanye iklan lokal yang sesuai dengan budaya dan preferensi pelanggan di area tersebut. Selain itu, perusahaan dapat meningkatkan saluran distribusi dan kerjasama dengan mitra lokal untuk menjangkau pelanggan yang lebih luas. Penelitian lebih lanjut mengenai preferensi dan kebutuhan pelanggan di wilayah tersebut juga akan sangat bermanfaat dalam menciptakan penawaran produk yang lebih relevan dan menarik. Dengan cara ini, perusahaan dapat memperluas pangsa pasar dan meningkatkan jumlah pelanggan secara keseluruhan.
# * Hasil analisis RFM menunjukkan bahwa banyak pelanggan memiliki nilai recency tinggi, mengindikasikan bahwa mereka belum melakukan pembelian dalam waktu lama. Hal ini menunjukkan potensi kehilangan pelanggan setia. Rata-rata frekuensi pembelian yang rendah, sekitar 1-2 kali, menunjukkan perlunya fokus pada strategi retensi untuk mengubah pembeli pertama kali menjadi pelanggan loyal.
# Dari segi pengeluaran, nilai monetary menunjukkan adanya potensi peningkatan kontribusi pendapatan per pelanggan. Untuk itu, perusahaan dapat menerapkan program loyalitas dan strategi cross-selling serta up-selling untuk mendorong frekuensi dan nilai transaksi.Dengan memahami pola ini, perusahaan dapat mengoptimalkan strategi pemasaran dan meningkatkan retensi pelanggan, sehingga meraih pertumbuhan pendapatan yang berkelanjutan.
